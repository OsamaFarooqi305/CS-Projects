# %%
import json

# %%
#Load the user's json data 
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)
        return data

# %%
data = load_data("data.json")

# %%
#Display the users data in a readable format
def display_user(data):
    for user in data['users']:
        print(f"ID:{user['id']}-{user['name']} is friends with {user['friends']} and the likedpages are {user['liked_pages']}")
    print("\nPages Information")

    for page in data['pages']:
            print(f"{page['id']}-{page['name']}")

# %%
display_user(data)
# Out:
# ID:1-Amit is friends with [2, 3, 4, 5, 6] and the likedpages are [101, 102]
# ID:2-Priya is friends with [1, 3, 5, 6, 7] and the likedpages are [102, 103]
# ID:3-Rahul is friends with [1, 2, 4, 7, 8] and the likedpages are [101, 103]
# ID:4-Sara is friends with [1, 3, 6, 8, 9] and the likedpages are [104]
# ID:5-Neha is friends with [1, 2, 6, 10, 11] and the likedpages are [102, 105]
# ID:6-Vikram is friends with [1, 2, 4, 5, 12] and the likedpages are [106]
# ID:7-Kunal is friends with [2, 3, 8, 9, 13] and the likedpages are [101, 107]
# ID:8-Anjali is friends with [3, 4, 7, 10, 14] and the likedpages are [103, 108]
# ID:9-Ravi is friends with [4, 7, 10, 11, 15] and the likedpages are [104, 109]
# ID:10-Sneha is friends with [5, 8, 9, 12, 16] and the likedpages are [110]
# ID:11-Arjun is friends with [5, 9, 12, 14, 17] and the likedpages are [105, 111]
# ID:12-Meera is friends with [6, 10, 11, 13, 18] and the likedpages are [112]
# ID:13-Kabir is friends with [7, 12, 14, 15, 19] and the likedpages are [106, 113]
# ID:14-Tanya is friends with [8, 11, 13, 16, 20] and the likedpages are [114]
# ID:15-Varun is friends with [9, 13, 16, 17, 21] and the likedpages are [107, 115]
# ID:16-Rhea is friends with [10, 14, 15, 18, 22] and the likedpages are [116]
# ID:17-Ishan is friends with [11, 15, 18, 19, 23] and the likedpages are [108, 117]
# ID:18-Simran is friends with [12, 16, 17, 20, 24] and the likedpages are [118]
# ID:19-Pooja is friends with [13, 17, 20, 21, 25] and the likedpages are [109, 119]
# ID:20-Yash is friends with [14, 18, 19, 22, 26] and the likedpages are [120]
# ID:21-Ananya is friends with [15, 19, 22, 23, 27] and the likedpages are [110, 121]
# ID:22-Dev is friends with [16, 20, 21, 24, 28] and the likedpages are [122]
# ID:23-Aditi is friends with [17, 21, 24, 25, 29] and the likedpages are [111, 123]
# ID:24-Rohan is friends with [18, 22, 23, 26, 30] and the likedpages are [124]
# ID:25-Nisha is friends with [19, 23, 26, 27, 1] and the likedpages are [112]
# ID:26-Gautam is friends with [20, 24, 25, 28, 3] and the likedpages are [125]
# ID:27-Kriti is friends with [21, 25, 28, 29, 5] and the likedpages are [113]
# ID:28-Harsh is friends with [22, 26, 27, 30, 7] and the likedpages are [126]
# ID:29-Naveen is friends with [23, 27, 30, 9, 11] and the likedpages are [114]
# ID:30-Ishita is friends with [24, 28, 29, 13, 15] and the likedpages are [127]
#
# Pages Information
# 101-Python Developers
# 102-Data Science Enthusiasts
# 103-AI & ML Community
# 104-Web Dev Hub
# 105-Blockchain Innovators
# 106-Cybersecurity Experts
# 107-Cloud Computing Pros
# 108-Competitive Programmers
# 109-Startup Founders
# 110-UI/UX Designers
# 111-Full-Stack Developers
# 112-Tech Entrepreneurs
# 113-IoT Enthusiasts
# 114-Game Developers
# 115-Big Data Analysts
# 116-DevOps Engineers
# 117-Cloud AI Researchers
# 118-5G & Edge Computing
# 119-AR/VR Creators
# 120-Freelance Coders
# 121-Open Source Contributors
# 122-Algorithmic Traders
# 123-Low-Code Developers
# 124-Cyber Ethics Forum
# 125-AI Ethics & Policy
# 126-Digital Nomads
# 127-Women in Tech

# %%
#Cleaning and structuring the data
def clean_data(data):
    #Remove users with missing names
    data["users"] = [user for user in data["users"] if user["names"].strip()]
    #Remove duplicate friends
    for user in data["users"]:
        user["friends"] = list(set(user["friends"]))
    #Remove inactive users
    data["users"] = [user for user in data["users"] if user["friends"] or user["liked_pages"]]
    #Remove duplicate pages
    unique_pages = {}
    for page in data["pages"]:
        unique_pages[page["id"]] = page
        data["pages"] = list(unique_pages.values())
        return data
        #Load,clean,display the data
        data = json.load(open("data.json"))
        data = clean_data(data)
        json.dump(data,open("data.json","w"),indent = 4)
print("Data Cleaned Successfully!")
# Out:
# Data Cleaned Successfully!

# %%
#Finding "People you may know"
def load_data(filename):
    with open(filename, "r") as file:
        return json.load(file)

def find_people_you_may_know(user_id, data):
    user_friends = {}
    for user in data["users"]:
        user_friends[user["id"]] = set(user["friends"])
    
    if user_id not in user_friends:
        return []
    
    direct_friends = user_friends[user_id]
    suggestions = {}
    
    for friend in direct_friends:
        #For all friends of friend
        for mutual in user_friends[friend]:
            #If mutual id is not the same user and not already a direct friend of user
            if mutual != user_id and mutual not in direct_friends:
                #Count mutual friends
                suggestions[mutual] = suggestions.get(mutual, 0) + 1
    
    sorted_suggestions = sorted(suggestions.items(), key=lambda x: x[1], reverse=True)
    return [user_id for user_id, _ in sorted_suggestions]

#Load data
data = load_data("data.json")
user_id = 2  # Example: Finding suggestions for Amit
recommendations = find_people_you_may_know(user_id, data)
print(f"People You May Know for User {user_id}: {recommendations}")
# Out:
# People You May Know for User 2: [4, 8, 10, 11, 12, 9, 13]

# %%
#Finding "Pages you might like"
def load_data(filename):
    with open(filename, "r") as file:
        return json.load(file)

#Function to find pages a user might like based on common interests
def find_pages_you_might_like(user_id, data):
    #Dictionary to store user interactions with pages
    user_pages = {}
    for user in data["users"]:
        user_pages[user["id"]] = set(user["liked_pages"])
    
    #If the user is not found, return an empty list
    if user_id not in user_pages:
        return []
    
    user_liked_pages = user_pages[user_id]
    page_suggestions = {}
    
    for other_user, pages in user_pages.items():
        if other_user != user_id:
            shared_pages = user_liked_pages.intersection(pages)
            for page in pages:
                if page not in user_liked_pages:
                    page_suggestions[page] = page_suggestions.get(page, 0) + len(shared_pages)
    
    #Sort recommended pages based on the number of shared interactions
    sorted_pages = sorted(page_suggestions.items(), key=lambda x: x[1], reverse=True)
    return [page_id for page_id, _ in sorted_pages]

#Load data
data = load_data("data.json")
user_id = 2  # Example: Finding recommendations for Amit
page_recommendations = find_pages_you_might_like(user_id, data)
print(f"Pages You Might Like for User {user_id}: {page_recommendations}")
# Out:
# Pages You Might Like for User 2: [101, 105, 108, 104, 106, 107, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127]
